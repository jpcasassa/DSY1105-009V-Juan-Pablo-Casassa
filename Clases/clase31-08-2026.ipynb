// %%
Control de Errores (safeNull)

val texto = "123H"
var numero = texto.toIntOrNull()

if (numero != null) {
    // Se pudo convertir
} else {
    // No se pudo convertir
}

    }
}

try {
    val texto = "123H"
    var numero = texto.toInt()
}catch (n.NumberFormatException){

}

//Clase de datos -> DTO

dataclassPersona{
    val nombre : String
}

//Sealed Class
//Conjunto cerrado de tipo

Sealed class Resultado

classExito
classError

var resultado =
when(Resultado)
