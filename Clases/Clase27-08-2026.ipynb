// %%
var lista = ListOf("Hola","Chao") "Listas Inmutables"
var mlista = mutableListOf(....) "Listas Mutables"

mLista.add()
mlista.remove()

for(el in lista){
    lista.forEach{
    }
    Lista.Filter{
        el > el.lengh>5
    }
    list.count{
        el el.startwith()
    }
}

// POO > kotlin
class Alumno {
    val nombre : String
    val rut: String
    var fecNac : String

    fun calcularEdad(){
        return fecNac - now()
    }
    fun validarRut(){
        return true
    }
}

// Contructor en kotlin
class alumno(
    val nombre: String
    val rut: String
    val fecNac: String
)

// Encapsulamiento en kotlin
class Cuenta(saldoInicial:Int){
    private var saldo = saldoInicial

    fun girar(monto:Int){
        if(permitidoGirar(Monto)){

        }
    }
    fun permitidoGirar(Monto:Int){
        return.monto> o && monto <= saldo
    }
}

// Herencias

extends
implements

open class Cuenta(saldoInicial: Int) {
    private var saldo = saldoInicial

    open fun permitidoGirar(monto: Int): Boolean {
        return monto > 0 && monto <= saldo
    }

    open fun girar(monto: Int): Int {
        if (permitidoGirar(monto)) {
            saldo -= monto
        }

        return saldo
    }
}
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[1], line 1, column 35: Property getter or setter expected
// at Cell In[1], line 2, column 28: Expecting an argument
// at Cell In[1], line 2, column 28: Expecting ')'
// at Cell In[1], line 2, column 32: Expecting an element
// at Cell In[1], line 2, column 32: Property getter or setter expected
// at Cell In[1], line 14, column 14: Expecting an element
// at Cell In[1], line 14, column 25: Expecting an expression
// at Cell In[1], line 34, column 23: Expecting comma or ')'
// at Cell In[1], line 35, column 20: Expecting comma or ')'
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:157)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:127)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute_W38Nk0s$lambda$0$1(CellExecutorImpl.kt:95)
// ...
